# %% [markdown]
# #  <center> <font color =  darkbrown> **W4T4 W4T4 Kaggle API**
#
#
#
# ---
#
# ---
# ## <center> <font color =  green>By Vipul Arora
# ### <center> <font color =  green>Sep 23 2023
#  ### <center> <font color =  green>DSA 501 Fall 2023

# %% [markdown]
# <font color =  green> Using the package kaggle

# %%
# @title
# !kaggle datasets list -s apple
# Out:
# ref                                                      title                                       size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -----------------------------------------  -----  -------------------  -------------  ---------  ---------------
# varpit94/apple-stock-data-updated-till-22jun2021         APPLE Stock Data                           205KB  2022-03-25 16:13:47           3144         51  1.0
# gauthamp10/apple-appstore-apps                           Apple AppStore Apps                        117MB  2021-10-14 07:28:30           2490         36  0.85294116
# tarunpaparaju/apple-aapl-historical-stock-data           Apple (AAPL) Historical Stock Data          49KB  2020-02-29 08:58:43           9380         72  1.0
# soheiltehranipour/apple-stock-20132018                   Apple Stock (2013-2018)                      7KB  2022-08-12 09:40:44            753         37  0.875
# ...

# %%
# @title
# !kaggle datasets download -d aleespinosa/apple-watch-and-fitbit-data -p /content
# Out:
# ...
#   0% 0.00/700k [00:00<?, ?B/s]
# 100% 700k/700k [00:00<00:00, 137MB/s]

# %%
# @title
# !unzip \*.zip
# Out:
# Archive:  apple-watch-and-fitbit-data.zip
#   inflating: aw_fb_data.csv
#   inflating: data_for_weka_aw.csv
#   inflating: data_for_weka_fb.csv

# %%
# @title
ap_watch=pd.read_csv('data_for_weka_aw.csv')

# %%
# @title
fb_watch=pd.read_csv('data_for_weka_fb.csv')

# %%
# @title
df=pd.read_csv('aw_fb_data.csv')

# %% [markdown]
# # <center>![Unknown-8.jpeg](data:image/jpeg;base64,...)
# # <center> FitBit Vs Apple

# %%
# @title
# APPL watch
ap_watch.head()
# Out:
#    Unnamed: 0  age  gender  height  weight  Applewatch.Steps_LE  \
# 0           1   20       1   168.0    65.4            10.771429
# 1           2   20       1   168.0    65.4            11.475325
# 2           3   20       1   168.0    65.4            12.179221
# 3           4   20       1   168.0    65.4            12.883117
# 4           5   20       1   168.0    65.4            13.587013
#
#    Applewatch.Heart_LE  Applewatch.Calories_LE  Applewatch.Distance_LE  \
# 0            78.531302                0.344533                0.008327
# 1            78.453390                3.287625                0.008896
# 2            78.540825                9.484000                0.009466
# 3            78.628260               10.154556                0.010035
# 4            78.715695               10.825111                0.010605
#
#    EntropyApplewatchHeartPerDay_LE  EntropyApplewatchStepsPerDay_LE  \
# 0                         6.221612                         6.116349
# ...

# %%
# @title
fb_watch.head()
# Out:
#    Unnamed: 0  age  gender  height  weight  Fitbit.Steps_LE  Fitbit.Heart_LE  \
# 0           1   20       1   168.0    65.4              1.0       132.000000
# 1           2   20       1   168.0    65.4              1.0       132.777778
# 2           3   20       1   168.0    65.4              1.0       129.888889
# 3           4   20       1   168.0    65.4              1.0       129.142857
# 4          11   20       1   168.0    65.4              1.0       134.555556
#
#    Fitbit.Calories_LE  Fitbit.Distance_LE  EntropyFitbitHeartPerDay_LE  \
# 0                 1.0                 1.0                     5.938588
# 1                 1.0                 1.0                     5.938588
# 2                 1.0                 1.0                     5.938588
# 3                 1.0                 1.0                     5.938588
# 4                 3.5                 1.0                     5.938588
#
#    EntropyFitbitStepsPerDay_LE  RestingFitbitHeartrate_LE  \
# ...

# %%
# @title
df.tail()
# Out:
#       Unnamed: 0    X1  age  gender  height  weight  steps  hear_rate  \
# 6259        6260  3666   46       0   157.5    71.4    1.0       35.0
# 6260        6261  3667   46       0   157.5    71.4    1.0       35.0
# 6261        6262  3668   46       0   157.5    71.4    1.0       35.0
# 6262        6263  3669   46       0   157.5    71.4    1.0       35.0
# 6263        6264  3670   46       0   157.5    71.4    1.0       35.0
#
#       calories  distance  entropy_heart  entropy_setps  resting_heart  \
# 6259      20.5       1.0            0.0            0.0           35.0
# 6260      20.5       1.0            0.0            0.0           35.0
# 6261      20.5       1.0            0.0            0.0           35.0
# 6262      20.5       1.0            0.0            0.0           35.0
# 6263      20.5       1.0            0.0            0.0           35.0
#
#       corr_heart_steps  norm_heart  intensity_karvonen  sd_norm_heart  \
# ...

# %%
# @title
ap_watch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3656 entries, 0 to 3655
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              3656 non-null   int64
#  1   age                                     3656 non-null   int64
#  2   gender                                  3656 non-null   int64
#  3   height                                  3656 non-null   float64
#  4   weight                                  3656 non-null   float64
#  5   Applewatch.Steps_LE                     3656 non-null   float64
#  6   Applewatch.Heart_LE                     3656 non-null   float64
#  7   Applewatch.Calories_LE                  3656 non-null   float64
#  8   Applewatch.Distance_LE                  3656 non-null   float64
#  9   EntropyApplewatchHeartPerDay_LE         3656 non-null   float64
# ...

# %%
# @title
fb_watch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2608 entries, 0 to 2607
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          2608 non-null   int64
#  1   age                                 2608 non-null   int64
#  2   gender                              2608 non-null   int64
#  3   height                              2608 non-null   float64
#  4   weight                              2608 non-null   float64
#  5   Fitbit.Steps_LE                     2608 non-null   float64
#  6   Fitbit.Heart_LE                     2608 non-null   float64
#  7   Fitbit.Calories_LE                  2608 non-null   float64
#  8   Fitbit.Distance_LE                  2608 non-null   float64
#  9   EntropyFitbitHeartPerDay_LE         2608 non-null   float64
#  10  EntropyFitbitStepsPerDay_LE         2608 non-null   float64
# ...

# %%
# @title
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6264 entries, 0 to 6263
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            6264 non-null   int64
#  1   X1                    6264 non-null   int64
#  2   age                   6264 non-null   int64
#  3   gender                6264 non-null   int64
#  4   height                6264 non-null   float64
#  5   weight                6264 non-null   float64
#  6   steps                 6264 non-null   float64
#  7   hear_rate             6264 non-null   float64
#  8   calories              6264 non-null   float64
#  9   distance              6264 non-null   float64
#  10  entropy_heart         6264 non-null   float64
#  11  entropy_setps         6264 non-null   float64
#  12  resting_heart         6264 non-null   float64
#  13  corr_heart_steps      6264 non-null   float64
# ...

# %%
# @title
fb_watch=fb_watch.drop(['Unnamed: 0'],axis=1)

# %%
# @title
ap_watch=ap_watch.drop(['Unnamed: 0'],axis=1)

# %%
# @title
df=df.drop(['Unnamed: 0','X1'],axis=1)

# %%
# @title
import plotly.graph_objects as go
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns

# %%
# @title
fb_watch['activity_trimmed'].value_counts()
# Out:
# Lying             592
# Running 7 METs    501
# Running 5 METs    399
# Running 3 METs    378
# Sitting           378
# Self Pace walk    360
# Name: activity_trimmed, dtype: int64

# %%
# @title
ap_watch['activity_trimmed'].value_counts()
# Out:
# Lying             787
# Running 7 METs    613
# Running 5 METs    603
# Running 3 METs    572
# Sitting           552
# Self Pace walk    529
# Name: activity_trimmed, dtype: int64

# %%
# @title
labels = ['Lying', 'Running 7 METs', 'Running 5 METs', 'Running 3 METs', 'Sitting', 'Self Pace walk']
values = ap_watch['activity_trimmed'].value_counts()
colors = ['red', 'royalblue', 'green', 'yellow', 'pink', 'grey']

fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=0.5)])
fig.update_traces(hoverinfo='label+value', textfont_size=15, marker=dict(colors=colors))

# Update the layout to add a title
fig.update_layout(
    title='Apple Watch 6 Types of Activity',  # Add your desired title here
    annotations=[dict(text='AW 6 types of Activity', x=0.50, y=0.5, font_size=15, showarrow=False)]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
labels = ['Lying', 'Running 7 METs', 'Running 5 METs', 'Running 3 METs', 'Sitting', 'Self Pace walk']
values = fb_watch['activity_trimmed'].value_counts()
colors = ['red', 'royalblue', 'green', 'yellow', 'pink', 'grey']

fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=0.5)])
fig.update_traces(hoverinfo='label+value', textfont_size=15, marker=dict(colors=colors))

# Update the layout to add a title
fig.update_layout(
    title='Fit Bit 6 Types of Activity',  # Add your desired title here
    annotations=[dict(text='fb 6 types of Activity', x=0.50, y=0.5, font_size=15, showarrow=False)]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.describe().transpose()
# Out:
#                        count        mean          std         min         25%  \
# age                   6264.0   29.158525     8.908978   18.000000   23.000000
# gender                6264.0    0.476533     0.499489    0.000000    0.000000
# height                6264.0  169.709052    10.324698  143.000000  160.000000
# weight                6264.0   69.614464    13.451878   43.000000   60.000000
# steps                 6264.0  109.562268   222.797908    1.000000    5.159534
# hear_rate             6264.0   86.142331    28.648385    2.222222   75.598079
# calories              6264.0   19.471823    27.309765    0.056269    0.735875
# distance              6264.0   13.832555    45.941437    0.000440    0.019135
# entropy_heart         6264.0    6.030314     0.765574    0.000000    6.108524
# entropy_setps         6264.0    5.739984     1.256348    0.000000    5.909440
# resting_heart         6264.0   65.869938    21.203017    3.000000   58.134333
# ...

# %%
for col in df.select_dtypes('object'):
    plt.figure()
    df[col].value_counts().plot.pie()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
sns.countplot(ax=axs[0],x='age', hue='activity', data=df)
sns.countplot(ax=axs[1],x='gender', hue='activity', data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.heatmap(pd.crosstab(df["activity"],df["device"]),annot=True,fmt='d')
# Out:
# <Axes: xlabel='device', ylabel='activity'>

# %%
# plt.rcParams.update({'font.size': 10})

sns.set(font_scale = 1)

df.hist(bins = 20, color = 'orange', figsize = (20, 14))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'height'}>,
#         <Axes: title={'center': 'weight'}>],
#        [<Axes: title={'center': 'steps'}>,
#         <Axes: title={'center': 'hear_rate'}>,
#         <Axes: title={'center': 'calories'}>,
#         <Axes: title={'center': 'distance'}>],
#        [<Axes: title={'center': 'entropy_heart'}>,
#         <Axes: title={'center': 'entropy_setps'}>,
#         <Axes: title={'center': 'resting_heart'}>,
#         <Axes: title={'center': 'corr_heart_steps'}>],
#        [<Axes: title={'center': 'norm_heart'}>,
#         <Axes: title={'center': 'intensity_karvonen'}>,
#         <Axes: title={'center': 'sd_norm_heart'}>,
#         <Axes: title={'center': 'steps_times_distance'}>]], dtype=object)

# %%
df_a = df[df['device']=='apple watch'].copy()
df_a.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.regplot(data = df_a, x='steps', y='distance')
plt.title('Distance Vs. Steps for Apple watch')
plt.tight_layout()

# %%
df_f = df[df['device']=='fitbit'].copy()
df_f.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.regplot(data = df_f, x='steps', y='distance')
plt.title('Distance Vs. Steps for Fitbit')
plt.tight_layout()
